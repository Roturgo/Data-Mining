# %% [markdown]
# ## INFS 770 - Assignment 3
#
# **Note**: Created using Anaconda Python 3.7.3 (64-bit)

# %% [markdown]
# ---

# %% [markdown]
# ### Pre-task setup

# %%
# Imports
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import gensim
from gensim.models import LdaModel, LsiModel
from pprint import pprint

# Sci-Py Packages
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

# nltk packages
import nltk
from nltk import word_tokenize 
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import FreqDist

# %%
# download nltk data first
# Note: ran once, then commented out for future notebook runs
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# ### T1 - read in & print textfile data

# %%
# Load text data
text_file = open("reviews.txt", "r")
docs = text_file.readlines()
text_file.close()

# %%
# Make sure we've got data
print("Number of lines in document:", len(docs))
# Out:
# Number of lines in document: 235

# %%
# Pretty print out the data
pprint(docs)
# Out:
# ['with all the available applications and new updates for its software , '
#  'iphone is a phone you grow with , not out of .\n',
#  'i upgraded from the sd550 canon there is not comparisent  .\n',
#  'i have also converted my office from the pc and windows world to mac os and '
#  'that is the best business decision i have made in years i have tried other '
#  'phones with android , windows mobile and they all fall short  .\n',
#  "i've also experienced the unit occasionally freezing or resetting itself , "
#  "usually when the bluetooth connection is active and i'm receiving a phone "
#  'call  .\n',
#  "this is my family's seventh (at least) garmin unit , and may be our last .\n",
#  'thanks canon for making my family happy and able to share our family photos '
#  'again  .\n',
#  'a really great camera  .\n',
#  'so i knew when i is buying this unit i is not buying a unit that i would '
#  'build for this price but the best available as far as it being balanced in   '
#  ', efficientcy and bells and whisles  .\n',
#  '(i have one , and i will also be getting the iphone 4g as soon as it comes '
#  'out as well) it is by far the best mobile that is currently on offer , and i '
#  'can see the 4g carrying on that legacy .\n',
#  'for the same $30 dollars a month for unlimited data plan , i get way more '
#  'out of my iphone than a blackberry  .\n',
#  "i've been researching digital camera's for quite some time but couldn't "
#  'quite make up my mind  .\n',
#  'the cannon sd790is very easy to operate in auto mode  .\n',
#  'i do not know anyone who has one who wants to trade one , and for most users '
#  "the lack of multitasking is no big deal (it's a smart phone , not a tiny "
#  'pc)  .\n',
#  'bought this camera hours before going to nyc and found it very easy to use '
#  'and it took great pictures  .\n',
#  'just returned from 2 weeks in seattle/alaska  .\n',
#  'i could not imagine a better phone .\n',
#  'i have a canon slr but not easy to carry around , esp  .\n',
#  'the iphone is a great phone  .\n',
#  'so i is looking for a easy point and shot camera  .\n',
#  '00 for everthing period and they would still make a fortune as to all the '
#  'iphone haters and bashers out there , keep you second rate devices and i '
#  'will keep on using my world class phone and enjoy it everytime someone ask '
#  'me is that the iphone and i proudly say yes it is .\n',
#  'highly recommended  .\n',
#  'well this machine costed about 459  .\n',
#  'so do i like the machine  .\n',
#  'lastly , flash support  .\n',
#  'as a little side    note   the picture files are pretty large (i shoot at '
#  'the max quality) , so i invested in an 8 gb sdhc card and get 1745 pictures '
#  'before purging if you are wondering about the screen thing , i have put this '
#  'camera through thick and thin (left in overnight in a 10    below 0 degrees '
#  'f garage , dropped (in a small case) , and it has been hit (through a 1/2 '
#  'inch of neoprene not much protection there) , and i noticed some blue spots '
#  'on my screen (not like dead pixels , but splotches)  .\n',
#  'without the iphone , apps would not be as we know them today  .\n',
#  'another groundbreaking movement started by the iphone is design  .\n',
#  'so far so good and for $179 at costco a great deal .\n',
#  'its good for all events if you want a picture taken right away  .\n',
#  'the pictures it takes are fantastic , and they have great quality  .\n',
#  "no it doesn't i like it    i just wish they fine tuned odds and ends a bit "
#  "as far as the ad's yes i've heard complaints about it and to be perfectly "
#  "honest the ad's are paying or the 2 year free service  .\n",
#  'the ads do not bother me if the online services actually worked and would '
#  'keep the service free  .\n',
#  'i recommend it to any iphone owner  .\n',
#  'you can access another app while on a call and not loose the phone call  .\n',
#  'so far all the pictures have turned out great  .\n',
#  'they are placed with the headphone jack , and the dock connector , and is '
#  'exposed to the exterior environment , often in    correctly setting of the '
#  'sensor with the smallest of rain drops , or even humidity  .\n',
#  'i searched everywhere for a camera that i wanted and i fell apon this one '
#  'and i loved everything i is hearing about it , the main reviews that were '
#  'bad is about the battery life , and i agree with that  .\n',
#  'what i wish garmin did is put the gas prices and resturant searches in '
#  'distant order  .\n',
#  'the iphone can be picked up by anyone , and they could learn how to use the '
#  'phone within a few minutes  .\n',
#  'i text a lot so i is looking forward to using the qwerty keyboard on the '
#  'iphone  .\n',
#  'http  //nikeshoes2u  .\n',
#  'having had blackberry 8900 for almost an year and switched to iphone , i '
#  'gotta admit the better user experience iphone offers  .\n',
#  "they are not putting the ad's on to subisdize the unit  .\n",
#  'to start off , the software iphone uses is very straight forward and almost '
#  'never lags  .\n',
#  'forget megapixels and go for a camera w/ the features you need  .\n',
#  'there is simply so much more to do on iphone  .\n',
#  'also it works great in the dark and light  .\n',
#  'i love the angular look of the camera , and the video is amazing (the mic '
#  'faces backwards , yet still gets all the sound  .\n',
#  'if route calculated it will sometimes put me on route when i am on feeder '
#  'road or the other way around , i am on the highway and it puts me on the '
#  'feeder  .\n',
#  'i just bought this camera and have been playing with it a few weeks now  .\n',
#  'iphone have over 100 , 000+ (and growing) applications in their app store , '
#  'most of them are cheaply priced or free  .\n',
#  'i took over 600 pictures in 2 days and only had to recharge once .\n',
#  'oh well i brought a birthday present for me when i went to hide my 765t from '
#  'the car wash people and the screen cracked  .\n',
#  'do they always use the best route  .\n',
#  "they don't show up when you are driving anyway so i do not know the big "
#  'deal  .\n',
#  'i spent a lot of time reading reviews on multiple cameras and narrowed down '
#  'the field to the sd790 is , sd 1100 is , and a fujifilm finepix 1000fd  .\n',
#  "but you know what garmin's private poi's were always outdated so i guess you "
#  'cannot ask for everything personally do i think for $500  .\n',
#  'the phone is amazing  .\n',
#  "i've used everything from high slr to these little compact types  .\n",
#  "he had a sd750 and he loved the thing which brought me over to the canon's i "
#  'actually bought the sd790 thinking it is the 750 when i got it from costco  '
#  '.\n',
#  'ps    not a griper but sent nikon 4 cameras withy the same failure , battery '
#  'door tabs broken , and they said not their problem  .\n',
#  'i would recommend it to anyone  .\n',
#  'i called verizon and they asked me to download the latest patch for the tour '
#  'which fixed it , i dont know how this will be after a year or so but at the '
#  'moment i look for every opportunity to jump into the car and use my new nuvi '
#  '1690 .\n',
#  'i have read the other reviews and , although they reflect they opinions of '
#  'the users , i feel they are somewhat unfounded  .\n',
#  'houston is notorious for its traffic issues and the accuracy of the traffic '
#  'delays as reflected during my commute are spot on  .\n',
#  'when i record myself playing piano , it has a weird sound with it but normal '
#  "recording is fine i'm about to go to europe and cannot wait to use this "
#  'fully and take great pictures of landscape and castles best camera for price '
#  ', usability , and picture quality  .\n',
#  'the traffic data is pretty accurate and seems to update frequently  .\n',
#  "the maps are accurate , the poi's are up to date , and the nuvilink services "
#  'are great  .\n',
#  'i can use it without all the mess of a lap top when i am going on a trip on '
#  'my motorcycle  .\n',
#  'to catch outdoor pictures for kids  .\n',
#  'the price is right and the images are , imho , amazing for this price range  '
#  '.\n',
#  'i love being able to check the weather and flight status before i get to the '
#  'airport  .\n',
#  'button layout is a nice change in my opinion  .\n',
#  "i've been using this product for about 2 months and it's been a good tool  "
#  '.\n',
#  "it is easy for this old man to use and lessen's my load when i travel.\n",
#  'i did a careful reviewed and tested a few cameras , finally bought this one  '
#  '.\n',
#  'i have been using the 1690 for about a month and i have experienced flawless '
#  'operation of the unit  .\n',
#  'i also like the flight status and gas price features there is a lot more '
#  'positives than i can remember the only thing that i is surprised at is at '
#  "the price i paid maybe garmin could've included a carrying case/sleeve to "
#  'protect it .\n',
#  'so i went with the garmins  .\n',
#  'i will say that apple needs to make improvements in the multitasking and '
#  'allow the end user to set up the phone the way they would like it to look '
#  'instead of the one way approach they currently have in place they have '
#  'become a 50 billion dollar company because they build stuff people want and '
#  'they stand behind what they build  .\n',
#  'all of these cameras have enough megapixels to print even big prints , and '
#  'they all have tiny lenses that are incapable of performance beyond a certain '
#  'point anyhow  .\n',
#  'i consider myself a user for life .\n',
#  'this is a great point and shoot camera  .\n',
#  'i spent a lot of top shopping for cameras in the $200 range  .\n',
#  'i choose this little camera because it is an ultra compact that is really '
#  'easy to carry and to use , you can ask anyone to take a picture with '
#  'excellent and consistent results  .\n',
#  'let me ask should you be looking at the road while driving or at the unit '
#  "would i recomend this product yeah it's cool  .\n",
#  'i find it very easy to use and do all my banking on it and pay , or check my '
#  'accounts  .\n',
#  'so it is constantly multi    tasking the core apps , and also lets you '
#  'access apps while on a phone call  .\n',
#  'this phone is very easy to use  .\n',
#  "the image just looks so much clearer on the large screen i've been testing "
#  'it for about a month now and i have been extremely impressed .\n',
#  'their is nothing to say but the iphone 4 is the best phone in the world  .\n',
#  'i called garmin and they said they had never heard of that problem but they '
#  'did exchange the unit for a new one  .\n',
#  'you wo not regret it .\n',
#  'the apple iphone continues to be the phone by which all other smart phones '
#  'are compared  .\n',
#  'i am really happy with the operation of the camera  .\n',
#  'droid is getting the market share nowadays , but iphone still is a pleasure '
#  'to use  .\n',
#  'app , etc) that are consistently running in the background  .\n',
#  'i switched from a motorola razr to the iphone 3gs 16gb so you should have an '
#  'idea of the leap in technology i experienced with the iphone .\n',
#  'the camera could be improved , as well as an addition of a flash to the '
#  'camera  .\n',
#  'thanks cnet for your accurate reviews and shopping assistance  .\n',
#  'the sd790is is another great canon camera in my opinion  .\n',
#  'the windshield mount is very solid and the cradle is easy to insert/detach '
#  'the unit from with one hand  .\n',
#  'the addition of the google search helps a lot i know this is cheesy but i '
#  'love the screen savers offer [makes the device more attractive]  .\n',
#  'approx 1500 to 2200 photos per canon so far    all loving family shots from '
#  'across the country  .\n',
#  'with thousands of developers , the capabilities for apps are endless  .\n',
#  'it had a terrible flicker on the screen when data is being transmitted.\n',
#  'after an hour of going back and forth between the 790 and the 1100 , i chose '
#  'the 790 for its much larger screen size (something that i have never really '
#  'cared about)  .\n',
#  'i would highly recommend this gps unit for anyone looking for a high    end '
#  'pnd .\n',
#  'it destroyed the comparable nikons beyond meeting all my initial criteria , '
#  'the sd790is has outstanding video and i have not experienced any problems '
#  'with the placement of the microphone pinhole and wind noise , as suggested '
#  'by the cnet review  .\n',
#  'i hope garmin will improve on this unit .\n',
#  "this doesn't happen often , maybe once a week or two  .\n",
#  'from the physical design to the software , the iphone is a well refined '
#  'phone  .\n',
#  'i am very happy with my choice .\n',
#  'while not of major concern , it would certainly be a great addition to the '
#  'phones already awesome browser .\n',
#  "they are in order in there own poi's but not in the google search poi.\n",
#  'like this product due to unmatchable canon photo quality  .\n',
#  'i bought this camera a couple months ago , and it has been really awesome  '
#  '.\n',
#  'everything is streamlined and runs smoothly  .\n',
#  'i have always been a big fan of the canon powershot series  .\n',
#  "i got is because it is soooooo cheep right now and cnet's great review of it "
#  'so far , i have not done anything serious with it yet but just take some '
#  'pics of me and my friends during our music program and do some youtube '
#  'videos  .\n',
#  'but video quality just kills it (note that if you want a camera for mainly '
#  'video recording , you should not even think about this camera and is not a '
#  'video camera)  .\n',
#  'also , there should be a multi carrier platform , at t has a great 3g '
#  'network , but that is if you can get a signal  .\n',
#  'enough of the bad talk about the iphone for reasons of call quality and '
#  'coverage , thats the network , not the phone  .\n',
#  'the sd790is far surpasses the sd550  .\n',
#  'i am so pleased with the pictures    clear , balanced , no shake all the '
#  'things i need as an amateur photographer and parent on the move highly '
#  'recommend  .\n',
#  "i like the new feel' of the graphical ui and the menus are well laid out  "
#  '.\n',
#  "since i started buying gps's i had to lower my standards or i'd be on anti "
#  'depressants for the rest of my life lol to start with all the nuvi products '
#  'route you the same  .\n',
#  'just to recap when i speak of routing i am speaking for all garmins '
#  "including this one selling points i like the screen it's bright and the "
#  'letters are big , i love the traffic that you get via built in celluar band '
#  ", i love the google search , i havan't tried blue tooth but i will in a few "
#  "years when i'm board , theh speaker quality is good  .\n",
#  '00 but whatever  .\n',
#  'this is the best best best little camera  .\n',
#  'i have not been happy with this one  .\n',
#  '(it only does this if a route is calculated)  .\n',
#  'i love almost every aspect of it  .\n',
#  'but they all do most of the time the routes were good , even when they were '
#  'not that good they were ok  .\n',
#  'if i tell the device to always display traffic data it will sometimes reboot '
#  'on me  .\n',
#  "but i guess it's better than $499  .\n",
#  'bluetooth didnt work well with my blackberry tour  .\n',
#  "well well i think i'm going to get in trouble with mom  .\n",
#  'my significant other is intimidated by this camera and as a result i end up '
#  'on the other side of the lens all the time and rarely appear in pictures '
#  'with my family what i got in the sd790is    .\n',
#  'i see all the iphone bashing going on in these reviews and most of it is '
#  'from folks who have never used one as a business tool like i do  .\n',
#  'btw if you want a great price for these go to your local costco  .\n',
#  'garmin has dropped the ball on this one  .\n',
#  'i brought it to best buy and the geek squad said it looked like moisture , '
#  'but needless to say they sent it out to be repaired , free of charge (even '
#  'though i bought the camera like 6 months ago)  .\n',
#  'i am a point and shoot photographer and this fits the bill without hurting '
#  'your pocket book  .\n',
#  'i finally had to go to an electronics store to test them all out for myself '
#  'the fuji is nice , but unimpressive  .\n',
#  "i'm writing this on c    ent and facebook and mom is listed as my friend  "
#  '.\n',
#  'firmware upgrades do not correct the reset problems , and i cannot get a '
#  'response from them via messages sent from their my garmin web site  .\n',
#  'if you have children or pets this camera is great  .\n',
#  'the window suction device is easy to use and it is easy to clip    in the '
#  'device and remove it as well  .\n',
#  'does it take you in circles yeah sometimes  .\n',
#  "but as much screaming i've done it get's me nowhere  .\n",
#  'it is a mini laptop  .\n',
#  'it is great  .\n',
#  "garmin's don't take you the back way (like i'd like to avoid traffic) and "
#  "even somtimes a slower way then i'd know (for example i'd use a highway to "
#  'connect with another highway) the garmin would tell me take a main road to '
#  'connect to the 2nd highway  .\n',
#  'all i have to say is the american companies have no pride in there '
#  'production anymore  .\n',
#  'this is a great phone , and if you have the opportunity to get your haands '
#  'on one , go for it  .\n',
#  "it's a little low for my standards but it's really awsum for what you can "
#  'expect in todays world  .\n',
#  'i have brightness maxed and rarely use flash , and get about 500+ shots per '
#  'charge  .\n',
#  'with the iphone you just do , you do not have to think about it  .\n',
#  "the big screen size is fantastic and doesn't seem to take a big hit off "
#  'battery life  .\n',
#  'the ease of use is one of the best parts of the phone  .\n',
#  '00 , i guess i could have gotton it for 399  .\n',
#  'the iphone is still the phone that does the basics in a world class fashion '
#  'and adds to the experience like only apple can (bt , wifi , apps , etc)  .\n',
#  'i know i could of gotten a 265wt for a $100  .\n',
#  'very east to use controls  .\n',
#  'the cellular issue is random , and will happen in spots where it works just '
#  'fine somedays and not on others  .\n',
#  'being able to comparison shop for fuel is great and has already saved me $$  '
#  '.\n',
#  "however the iphone is not without it's faults  .\n",
#  'i would definitely recommend this camera to my friends .\n',
#  'i is a loyal blackberry user for years before making the switch to apple and '
#  'i have never looked back  .\n',
#  'the color accent feature is also interesting to play with battery life is '
#  'significant , though i purchased an additional battery for reserve when '
#  'traveling out of country  .\n',
#  'com  .\n',
#  'they get you where you are going  .\n',
#  "i'm a point and shot kind of guy  .\n",
#  'battery life off    cradle has been about 2 hours  .\n',
#  'but , for a consumer that does not know a tad about hacking , i believe the '
#  'usability or a phone is way more important than raw tech spec  .\n',
#  'sometimes my traffic icon greys out , so far garmin just keeps sending me '
#  'new units which all do the same thing  .\n',
#  'i bought mine refurbished and i still dont have any complaints  .\n',
#  'im sorry but anyone giving a piece of technology this unbelievable needs '
#  'their head read  .\n',
#  'not a bad device , would be excelent if they would have gone with a better '
#  'cellular service  .\n',
#  'most of the negative reviews you see here will be from pre or android users  '
#  '.\n',
#  'buy yourself whatever card size you think you need and be happy with the '
#  'awesome quality of this camera  .\n',
#  'my last camera is a nikon coolpix 5700 , which captures great images in the '
#  'right conditions (imho) , but is intimidating to many people due to the less '
#  'than intuitive layout/design/controls for non    slr users  .\n',
#  'the iphone set the groundwork for apps in phones , and truly has changed the '
#  'smartphone industry  .\n',
#  "i couldn't be happier with the purchase the prices of sd cards are so cheap "
#  ", just don't even think of having the pathetic 32mb as a con  .\n",
#  "i'll be purchasing another 5 over the next couple of months  .\n",
#  "i've had tom tom and i did not like the interface but the 740 live ether had "
#  'the most rational routes due to iq or historacal routes the offer at other '
#  'times it is horrable , the megallans froze up  .\n',
#  'with thousands of developers , the capabilities for apps are endless .\n',
#  'this is the easiest to use , takes a great photo , and meets my needs very '
#  'well  .\n',
#  'the unit does a good job of routing and takes live traffic conditions into '
#  'account  .\n',
#  'the process went very smooth i have owned several garmin units and is very '
#  'happy with them  .\n',
#  'in full auto mode the sd790is takes outstanding images for the price what i '
#  'is looking for in a digital camera    .\n',
#  'if you are not a toy buff then just get yourself the cheap one they all '
#  'route you the same .\n',
#  'camera seems like it is built/constructed very well  .\n',
#  "it's an iphone    which by now is a reliable and known quantity  .\n",
#  '00 the routing should be perfect yes  .\n',
#  'great camera  .\n',
#  'it has so many features that are awesome   the touch screen works as it '
#  'should ; the touch    screen dialing and reception/audio is crisp clear  .\n',
#  "i'd recommend this to anyone .\n",
#  '00 that the google searches should be in order yes , do i think for $500  '
#  '.\n',
#  'i also love the fact that iphone receives a system update every year or so  '
#  '.\n',
#  "one of it's biggest plus's though , is the app store  .\n",
#  'we currently own to sonys and after becoming frustrated with por pictures we '
#  'decided to give canon a chance  .\n',
#  'but then my photographer buddy showed me what he uses when he is not using '
#  "pro cameras (like when he's on vacation)  .\n",
#  'i have found that if i turn the unit off and back on again in about 1 minute '
#  'the cellular reconnects and i gain access again  .\n',
#  'what it does not do is let you control what multi    tasks       i have yet '
#  'to see a need to do this , and am happy my phone does it for me .\n',
#  'people complain about signal but i generally have strong signals when my '
#  'friends have very low or none every thing that is customizable on it , i '
#  'have a personalized theme and background all my settings are configurable '
#  'and sbprefs allows me to toggle almost anything i want instantly , edge , 3g '
#  ', bluetooth , brightness , processes , ssh , wi    fi , autolock , rotation '
#  'its perfect  .\n',
#  'also , the placement of the water sensors , are truly ineffective  .\n',
#  'there are core apps (like phone  .\n',
#  'before the iphone , design is of least concern by manufactures  .\n',
#  'i loved the sd750 but i felt that the image stabilizer is missing the '
#  'sd790is is an all    metal (at least on the outside) camera  .\n',
#  'the garmins are more consitant  .\n',
#  "i've experienced poor voice quality when using the bluetooth function with "
#  "my phone    but it's better than the earpiece i is using before  .\n",
#  'evrything is amazing right now and nobody is happy louis ck  .\n',
#  'before i got mine , i is skeptical about the iphone , but once i got it , i '
#  'is blown away by the features  .\n',
#  'i hate to say this but the google email and calendar functions are much '
#  'nicer and streamlined on the iphone then on the google phones  .\n',
#  "don't worry much about what you read about the iphone not being able to "
#  'multi    task it can and it does multi    task  .\n',
#  'i am very happy with my new sd790 .\n',
#  "some other reviews have slammed the pop    up ads but frankly i've barely "
#  "noticed them    they only appear when the vehicle is stopped , and if i'm "
#  "looking at the unit when i'm stopped , i'm usually accessing one of the "
#  'screens that do not show ads , so for my purposes they are practically '
#  'invisible .\n',
#  'ease of use , sub 200 dollar price , and fantastic picture quality why    '
#  '.\n',
#  'double aa battery cameras are great for this purpose , but the battery life '
#  'of the sd790is makes this a non    issue , at least for my purposes the '
#  'display is big and beautiful , though i sometimes feel it is too forgiving '
#  'with questionable images i thoroughly recommend this camera if it fits your '
#  'needs .\n',
#  "if this is not replaced as new i'll look elsewhere for my next system as i "
#  'drive overe 30k a year  .\n',
#  'on one of the updates now when traffic is detected it displays traffic for '
#  'you , and when no traffic is does not display the green lines on the map  '
#  '.\n',
#  "traffic   i don't get it  . \n",
#  '00 but i needed it fast due to the fact my screen cracked and i needed it '
#  'for business  .\n',
#  'i acquired the nuvi 1690 at best buy as a replacement through the '
#  'performance service plan that i had purchased on the nuvi 865t  .\n',
#  'i used my phone unhacked for months and finally got sick of being restricted '
#  'by stupid apple restrictions if it was not for the jailbreaking community i '
#  'would like this phone but it would not be nearly as perfect  .\n',
#  'i like this camera b/c of the big screen on the back and because it takes ok '
#  'indoor pictures .\n',
#  'i hate at t because they nickel and dime me to death and with all the cell '
#  'phones and portable internet devices out there , there is no reason any '
#  'carrier should be charging more the 79  .\n',
#  'greatest point    and    shoot camera  .\n',
#  'at the time i switched to iphone there are many other choices out there with '
#  'better hardware  .\n',
#  'i would love to see apple just make a phone that any carrier can use and '
#  'quit lining themselves up with one carrier  .\n',
#  'how is that possible  .\n',
#  'love the little features like it tells you how much gas you used for the '
#  'trip and how much it actually cost you  .\n',
#  'perhaps nikon planned their name to anagram nikon  no kin  .\n']

# %% [markdown]
# ### T2

# %%
# Pre-processing goals:
# 1 - Remove punctuations
# 2 - Remove numbers
# 3 - Do a lemmatization
# 4 - Remove stop words
# 5 - Remove words appearing in only 1 document
# 6 - Remove words appearing in >90% of documents

def before_token(documents):
    # remove punctuations
    punctuationless = list(map(lambda x: " ".join(re.findall('\\b\\w\\w+\\b',x)), documents))
    # remove numbers
    return list(map(lambda x:re.sub('\\b[0-9]+\\b', '', x), punctuationless))
docs1 = before_token(docs)


class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t,"v") for t in word_tokenize(doc)]
stopwords = nltk.corpus.stopwords.words("english") # for removal
vectorizer = TfidfVectorizer(tokenizer=LemmaTokenizer(),
                             norm=None,
                             stop_words=stopwords,
                             max_df=0.9, # remove frequent words (> 90%)
                             min_df=1) # remove unique words

corpus_vect = vectorizer.fit_transform(docs1)
#print(corpus_vect) # sparse matrix
df_vect = pd.DataFrame(corpus_vect.toarray(), columns=vectorizer.get_feature_names())
#print(df_vect)

# %%
# Print the features (vectorizer.vocabulary) extracted based on TF-IDF
# examine the mapping of words to feature indexes
print("Extracted features: ")
pprint(vectorizer.vocabulary_)
# Out:
# Extracted features:
# {'1000fd': 0,
#  '16gb': 1,
#  '265wt': 2,
#  '2nd': 3,
#  '30k': 4,
#  '32mb': 5,
#  '3g': 6,
#  '3gs': 7,
#  '4g': 8,
#  '765t': 9,
#  '865t': 10,
#  'aa': 11,
#  'able': 12,
#  'accent': 13,
#  'access': 14,
#  'account': 15,
#  'accuracy': 16,
#  'accurate': 17,
#  'acquire': 18,
#  'across': 19,
#  'active': 20,
#  'actually': 21,
#  'ad': 22,
#  'add': 23,
#  'addition': 24,
#  'additional': 25,
#  'admit': 26,
#  'ads': 27,
#  'ago': 28,
#  'agree': 29,
#  'airport': 30,
#  'alaska': 31,
#  'allow': 32,
#  'almost': 33,
#  'already': 34,
#  'also': 35,
#  'although': 36,
#  'always': 37,
#  'amateur': 38,
#  'amaze': 39,
#  'american': 40,
#  'anagram': 41,
#  'android': 42,
#  'angular': 43,
#  'another': 44,
#  'anti': 45,
#  'anyhow': 46,
#  'anymore': 47,
#  'anyone': 48,
#  'anything': 49,
#  'anyway': 50,
#  'apon': 51,
#  'app': 52,
#  'appear': 53,
#  'apple': 54,
#  'applications': 55,
#  'approach': 56,
#  'approx': 57,
#  'apps': 58,
#  'around': 59,
#  'ask': 60,
#  'aspect': 61,
#  'assistance': 62,
#  'attractive': 63,
#  'audio': 64,
#  'auto': 65,
#  'autolock': 66,
#  'available': 67,
#  'avoid': 68,
#  'away': 69,
#  'awesome': 70,
#  'awsum': 71,
#  'back': 72,
#  'background': 73,
#  'backwards': 74,
#  'bad': 75,
#  'balance': 76,
#  'ball': 77,
#  'band': 78,
#  'bank': 79,
#  'barely': 80,
#  'bash': 81,
#  'bashers': 82,
#  'basics': 83,
#  'battery': 84,
#  'beautiful': 85,
#  'become': 86,
#  'behind': 87,
#  'believe': 88,
#  'bell': 89,
#  'best': 90,
#  'better': 91,
#  'beyond': 92,
#  'big': 93,
#  'biggest': 94,
#  'bill': 95,
#  'billion': 96,
#  'birthday': 97,
#  'bite': 98,
#  'blackberry': 99,
#  'blow': 100,
#  'blue': 101,
#  'bluetooth': 102,
#  'board': 103,
#  'book': 104,
#  'bother': 105,
#  'break': 106,
#  'bright': 107,
#  'brightness': 108,
#  'bring': 109,
#  'browser': 110,
#  'bt': 111,
#  'btw': 112,
#  'buddy': 113,
#  'buff': 114,
#  'build': 115,
#  'business': 116,
#  'button': 117,
#  'buy': 118,
#  'calculate': 119,
#  'calendar': 120,
#  'call': 121,
#  'camera': 122,
#  'cameras': 123,
#  'cannon': 124,
#  'canon': 125,
#  'capabilities': 126,
#  'capture': 127,
#  'car': 128,
#  'card': 129,
#  'care': 130,
#  'careful': 131,
#  'carrier': 132,
#  'carry': 133,
#  'case': 134,
#  'castle': 135,
#  'catch': 136,
#  'cell': 137,
#  'celluar': 138,
#  'cellular': 139,
#  'certain': 140,
#  'certainly': 141,
#  'chance': 142,
#  'change': 143,
#  'charge': 144,
#  'cheap': 145,
#  'cheaply': 146,
#  'check': 147,
#  'cheep': 148,
#  'cheesy': 149,
#  'children': 150,
#  'choice': 151,
#  'choices': 152,
#  'choose': 153,
#  'circle': 154,
#  'ck': 155,
#  'class': 156,
#  'clear': 157,
#  'clearer': 158,
#  'clip': 159,
#  'cnet': 160,
#  'color': 161,
#  'com': 162,
#  'come': 163,
#  'community': 164,
#  'commute': 165,
#  'compact': 166,
#  'company': 167,
#  'comparable': 168,
#  'compare': 169,
#  'comparisent': 170,
#  'comparison': 171,
#  'complain': 172,
#  'complaints': 173,
#  'con': 174,
#  'concern': 175,
#  'condition': 176,
#  'configurable': 177,
#  'connect': 178,
#  'connection': 179,
#  'connector': 180,
#  'consider': 181,
#  'consistent': 182,
#  'consistently': 183,
#  'consitant': 184,
#  'constantly': 185,
#  'construct': 186,
#  'consumer': 187,
#  'continue': 188,
#  'control': 189,
#  'convert': 190,
#  'cool': 191,
#  'coolpix': 192,
#  'core': 193,
#  'correct': 194,
#  'correctly': 195,
#  'cost': 196,
#  'costco': 197,
#  'could': 198,
#  'country': 199,
#  'couple': 200,
#  'coverage': 201,
#  'crack': 202,
#  'cradle': 203,
#  'crisp': 204,
#  'criteria': 205,
#  'currently': 206,
#  'customizable': 207,
#  'dark': 208,
#  'data': 209,
#  'date': 210,
#  'days': 211,
#  'dead': 212,
#  'deal': 213,
#  'death': 214,
#  'decide': 215,
#  'decision': 216,
#  'definitely': 217,
#  'degrees': 218,
#  'delay': 219,
#  'depressants': 220,
#  'design': 221,
#  'destroy': 222,
#  'detach': 223,
#  'detect': 224,
#  'developers': 225,
#  'device': 226,
#  'devices': 227,
#  'dial': 228,
#  'didnt': 229,
#  'digital': 230,
#  'dime': 231,
#  'display': 232,
#  'distant': 233,
#  'dock': 234,
#  'dollar': 235,
#  'dollars': 236,
#  'dont': 237,
#  'door': 238,
#  'double': 239,
#  'download': 240,
#  'drive': 241,
#  'droid': 242,
#  'drop': 243,
#  'due': 244,
#  'earpiece': 245,
#  'ease': 246,
#  'easiest': 247,
#  'east': 248,
#  'easy': 249,
#  'edge': 250,
#  'efficientcy': 251,
#  'electronics': 252,
#  'elsewhere': 253,
#  'email': 254,
#  'end': 255,
#  'endless': 256,
#  'enjoy': 257,
#  'enough': 258,
#  'ent': 259,
#  'environment': 260,
#  'esp': 261,
#  'etc': 262,
#  'ether': 263,
#  'europe': 264,
#  'even': 265,
#  'events': 266,
#  'everthing': 267,
#  'every': 268,
#  'everything': 269,
#  'everytime': 270,
#  'everywhere': 271,
#  'evrything': 272,
#  'example': 273,
#  'excelent': 274,
#  'excellent': 275,
#  'exchange': 276,
#  'expect': 277,
#  'experience': 278,
#  'expose': 279,
#  'exterior': 280,
#  'extremely': 281,
#  'face': 282,
#  'facebook': 283,
#  'fact': 284,
#  'failure': 285,
#  'fall': 286,
#  'family': 287,
#  'fan': 288,
#  'fantastic': 289,
#  'far': 290,
#  'fashion': 291,
#  'fast': 292,
#  'fault': 293,
#  'feature': 294,
#  'feeder': 295,
#  'feel': 296,
#  'fell': 297,
#  'felt': 298,
#  'fi': 299,
#  'field': 300,
#  'file': 301,
#  'finally': 302,
#  'find': 303,
#  'fine': 304,
#  'finepix': 305,
#  'firmware': 306,
#  'fit': 307,
#  'fix': 308,
#  'flash': 309,
#  'flawless': 310,
#  'flicker': 311,
#  'flight': 312,
#  'folks': 313,
#  'forget': 314,
#  'forgive': 315,
#  'forth': 316,
#  'fortune': 317,
#  'forward': 318,
#  'frankly': 319,
#  'free': 320,
#  'freeze': 321,
#  'frequently': 322,
#  'friend': 323,
#  'friends': 324,
#  'frustrate': 325,
#  'fuel': 326,
#  'fuji': 327,
#  'fujifilm': 328,
#  'full': 329,
#  'fully': 330,
#  'function': 331,
#  'gain': 332,
#  'garage': 333,
#  'garmin': 334,
#  'garmins': 335,
#  'gas': 336,
#  'gb': 337,
#  'geek': 338,
#  'generally': 339,
#  'get': 340,
#  'give': 341,
#  'go': 342,
#  'good': 343,
#  'google': 344,
#  'gotton': 345,
#  'gps': 346,
#  'graphical': 347,
#  'great': 348,
#  'greatest': 349,
#  'green': 350,
#  'grey': 351,
#  'griper': 352,
#  'groundbreaking': 353,
#  'groundwork': 354,
#  'grow': 355,
#  'guess': 356,
#  'guy': 357,
#  'haands': 358,
#  'hack': 359,
#  'hand': 360,
#  'happen': 361,
#  'happier': 362,
#  'happy': 363,
#  'hardware': 364,
#  'hate': 365,
#  'haters': 366,
#  'havan': 367,
#  'head': 368,
#  'headphone': 369,
#  'hear': 370,
#  'help': 371,
#  'hide': 372,
#  'high': 373,
#  'highly': 374,
#  'highway': 375,
#  'historacal': 376,
#  'hit': 377,
#  'honest': 378,
#  'hope': 379,
#  'horrable': 380,
#  'hour': 381,
#  'hours': 382,
#  'houston': 383,
#  'however': 384,
#  'http': 385,
#  'humidity': 386,
#  'hurt': 387,
#  'icon': 388,
#  'idea': 389,
#  'im': 390,
#  'image': 391,
#  'imagine': 392,
#  'imho': 393,
#  'important': 394,
#  'impress': 395,
#  'improve': 396,
#  'improvements': 397,
#  'incapable': 398,
#  'inch': 399,
#  'include': 400,
#  'indoor': 401,
#  'industry': 402,
#  'ineffective': 403,
#  'initial': 404,
#  'insert': 405,
#  'instantly': 406,
#  'instead': 407,
#  'interest': 408,
#  'interface': 409,
#  'internet': 410,
#  'intimidate': 411,
#  'intuitive': 412,
#  'invest': 413,
#  'invisible': 414,
#  'iphone': 415,
#  'iq': 416,
#  'issue': 417,
#  'jack': 418,
#  'jailbreaking': 419,
#  'job': 420,
#  'jump': 421,
#  'keep': 422,
#  'keyboard': 423,
#  'kid': 424,
#  'kill': 425,
#  'kin': 426,
#  'kind': 427,
#  'know': 428,
#  'lack': 429,
#  'lag': 430,
#  'landscape': 431,
#  'lap': 432,
#  'laptop': 433,
#  'large': 434,
#  'larger': 435,
#  'last': 436,
#  'lastly': 437,
#  'latest': 438,
#  'lay': 439,
#  'layout': 440,
#  'leap': 441,
#  'learn': 442,
#  'least': 443,
#  'leave': 444,
#  'legacy': 445,
#  'lens': 446,
#  'lenses': 447,
#  'less': 448,
#  'lessen': 449,
#  'let': 450,
#  'letter': 451,
#  'life': 452,
#  'light': 453,
#  'like': 454,
#  'line': 455,
#  'list': 456,
#  'little': 457,
#  'live': 458,
#  'load': 459,
#  'local': 460,
#  'lol': 461,
#  'look': 462,
#  'loose': 463,
#  'lot': 464,
#  'louis': 465,
#  'love': 466,
#  'low': 467,
#  'lower': 468,
#  'loyal': 469,
#  'mac': 470,
#  'machine': 471,
#  'main': 472,
#  'mainly': 473,
#  'major': 474,
#  'make': 475,
#  'man': 476,
#  'manufacture': 477,
#  'many': 478,
#  'map': 479,
#  'market': 480,
#  'max': 481,
#  'maxed': 482,
#  'may': 483,
#  'maybe': 484,
#  'meet': 485,
#  'megallans': 486,
#  'megapixels': 487,
#  'menus': 488,
#  'mess': 489,
#  'message': 490,
#  'metal': 491,
#  'mic': 492,
#  'microphone': 493,
#  'mind': 494,
#  'mine': 495,
#  'mini': 496,
#  'minute': 497,
#  'minutes': 498,
#  'miss': 499,
#  'mobile': 500,
#  'mode': 501,
#  'moisture': 502,
#  'mom': 503,
#  'moment': 504,
#  'month': 505,
#  'months': 506,
#  'motorcycle': 507,
#  'motorola': 508,
#  'mount': 509,
#  'move': 510,
#  'movement': 511,
#  'much': 512,
#  'multi': 513,
#  'multiple': 514,
#  'multitasking': 515,
#  'music': 516,
#  'name': 517,
#  'narrow': 518,
#  'nearly': 519,
#  'need': 520,
#  'needle': 521,
#  'negative': 522,
#  'neoprene': 523,
#  'network': 524,
#  'never': 525,
#  'new': 526,
#  'next': 527,
#  'nice': 528,
#  'nicer': 529,
#  'nickel': 530,
#  'nikeshoes2u': 531,
#  'nikon': 532,
#  'nikons': 533,
#  'nobody': 534,
#  'noise': 535,
#  'non': 536,
#  'none': 537,
#  'normal': 538,
#  'note': 539,
#  'nothing': 540,
#  'notice': 541,
#  'notorious': 542,
#  'nowadays': 543,
#  'nowhere': 544,
#  'nuvi': 545,
#  'nuvilink': 546,
#  'nyc': 547,
#  'occasionally': 548,
#  'odds': 549,
#  'offer': 550,
#  'office': 551,
#  'often': 552,
#  'oh': 553,
#  'ok': 554,
#  'old': 555,
#  'one': 556,
#  'online': 557,
#  'operate': 558,
#  'operation': 559,
#  'opinion': 560,
#  'opinions': 561,
#  'opportunity': 562,
#  'order': 563,
#  'os': 564,
#  'others': 565,
#  'outdated': 566,
#  'outdoor': 567,
#  'outside': 568,
#  'outstanding': 569,
#  'overe': 570,
#  'overnight': 571,
#  'owner': 572,
#  'parent': 573,
#  'part': 574,
#  'patch': 575,
#  'pathetic': 576,
#  'pay': 577,
#  'pc': 578,
#  'people': 579,
#  'per': 580,
#  'perfect': 581,
#  'perfectly': 582,
#  'performance': 583,
#  'perhaps': 584,
#  'period': 585,
#  'personalize': 586,
#  'personally': 587,
#  'pet': 588,
#  'phone': 589,
#  'photo': 590,
#  'photographer': 591,
#  'photos': 592,
#  'physical': 593,
#  'piano': 594,
#  'pick': 595,
#  'pics': 596,
#  'picture': 597,
#  'piece': 598,
#  'pinhole': 599,
#  'pixels': 600,
#  'place': 601,
#  'placement': 602,
#  'plan': 603,
#  'platform': 604,
#  'play': 605,
#  'please': 606,
#  'pleasure': 607,
#  'plus': 608,
#  'pnd': 609,
#  'pocket': 610,
#  'poi': 611,
#  'point': 612,
#  'poor': 613,
#  'pop': 614,
#  'por': 615,
#  'portable': 616,
#  'positives': 617,
#  'possible': 618,
#  'powershot': 619,
#  'practically': 620,
#  'pre': 621,
#  'present': 622,
#  'pretty': 623,
#  'price': 624,
#  'pride': 625,
#  'print': 626,
#  'private': 627,
#  'pro': 628,
#  'problem': 629,
#  'problems': 630,
#  'process': 631,
#  'product': 632,
#  'production': 633,
#  'products': 634,
#  'program': 635,
#  'protect': 636,
#  'protection': 637,
#  'proudly': 638,
#  'ps': 639,
#  'purchase': 640,
#  'purge': 641,
#  'purpose': 642,
#  'put': 643,
#  'quality': 644,
#  'quantity': 645,
#  'questionable': 646,
#  'quit': 647,
#  'quite': 648,
#  'qwerty': 649,
#  'rain': 650,
#  'random': 651,
#  'range': 652,
#  'rarely': 653,
#  'rate': 654,
#  'rational': 655,
#  'raw': 656,
#  'razr': 657,
#  'read': 658,
#  'really': 659,
#  'reason': 660,
#  'reboot': 661,
#  'recap': 662,
#  'receive': 663,
#  'reception': 664,
#  'recharge': 665,
#  'recomend': 666,
#  'recommend': 667,
#  'reconnects': 668,
#  'record': 669,
#  'refine': 670,
#  'reflect': 671,
#  'refurbish': 672,
#  'regret': 673,
#  'reliable': 674,
#  'remember': 675,
#  'remove': 676,
#  'repair': 677,
#  'replace': 678,
#  'replacement': 679,
#  'research': 680,
#  'reserve': 681,
#  'reset': 682,
#  'response': 683,
#  'rest': 684,
#  'restrict': 685,
#  'restrictions': 686,
#  'resturant': 687,
#  'result': 688,
#  'return': 689,
#  'review': 690,
#  'right': 691,
#  'road': 692,
#  'rotation': 693,
#  'rout': 694,
#  'route': 695,
#  'run': 696,
#  'save': 697,
#  'savers': 698,
#  'say': 699,
#  'sbprefs': 700,
#  'scream': 701,
#  'screen': 702,
#  'sd': 703,
#  'sd550': 704,
#  'sd750': 705,
#  'sd790': 706,
#  'sd790is': 707,
#  'sdhc': 708,
#  'search': 709,
#  'seattle': 710,
#  'second': 711,
#  'see': 712,
#  'seem': 713,
#  'sell': 714,
#  'send': 715,
#  'sensor': 716,
#  'sensors': 717,
#  'series': 718,
#  'serious': 719,
#  'service': 720,
#  'set': 721,
#  'settings': 722,
#  'seventh': 723,
#  'several': 724,
#  'shake': 725,
#  'share': 726,
#  'shoot': 727,
#  'shop': 728,
#  'short': 729,
#  'shots': 730,
#  'show': 731,
#  'sick': 732,
#  'side': 733,
#  'signal': 734,
#  'significant': 735,
#  'simply': 736,
#  'since': 737,
#  'site': 738,
#  'size': 739,
#  'skeptical': 740,
#  'slam': 741,
#  'sleeve': 742,
#  'slower': 743,
#  'slr': 744,
#  'small': 745,
#  'smallest': 746,
#  'smart': 747,
#  'smartphone': 748,
#  'smooth': 749,
#  'smoothly': 750,
#  'software': 751,
#  'solid': 752,
#  'somedays': 753,
#  'someone': 754,
#  'something': 755,
#  'sometimes': 756,
#  'somewhat': 757,
#  'somtimes': 758,
#  'sonys': 759,
#  'soon': 760,
#  'soooooo': 761,
#  'sorry': 762,
#  'sound': 763,
#  'speak': 764,
#  'speaker': 765,
#  'spec': 766,
#  'spend': 767,
#  'splotch': 768,
#  'spot': 769,
#  'squad': 770,
#  'ssh': 771,
#  'stabilizer': 772,
#  'stand': 773,
#  'standards': 774,
#  'start': 775,
#  'status': 776,
#  'still': 777,
#  'stop': 778,
#  'store': 779,
#  'straight': 780,
#  'streamline': 781,
#  'strong': 782,
#  'stuff': 783,
#  'stupid': 784,
#  'sub': 785,
#  'subisdize': 786,
#  'suction': 787,
#  'suggest': 788,
#  'support': 789,
#  'surpass': 790,
#  'surprise': 791,
#  'switch': 792,
#  'system': 793,
#  'ta': 794,
#  'tabs': 795,
#  'tad': 796,
#  'take': 797,
#  'talk': 798,
#  'task': 799,
#  'tech': 800,
#  'technology': 801,
#  'tell': 802,
#  'terrible': 803,
#  'test': 804,
#  'text': 805,
#  'thank': 806,
#  'thats': 807,
#  'theh': 808,
#  'theme': 809,
#  'thick': 810,
#  'thin': 811,
#  'thing': 812,
#  'things': 813,
#  'think': 814,
#  'thoroughly': 815,
#  'though': 816,
#  'thousands': 817,
#  'time': 818,
#  'tiny': 819,
#  'today': 820,
#  'todays': 821,
#  'toggle': 822,
#  'tom': 823,
#  'tool': 824,
#  'tooth': 825,
#  'top': 826,
#  'touch': 827,
#  'tour': 828,
#  'toy': 829,
#  'trade': 830,
#  'traffic': 831,
#  'transmit': 832,
#  'travel': 833,
#  'trip': 834,
#  'trouble': 835,
#  'truly': 836,
#  'try': 837,
#  'tune': 838,
#  'turn': 839,
#  'two': 840,
#  'type': 841,
#  'ui': 842,
#  'ultra': 843,
#  'unbelievable': 844,
#  'unfounded': 845,
#  'unhacked': 846,
#  'unimpressive': 847,
#  'unit': 848,
#  'units': 849,
#  'unlimited': 850,
#  'unmatchable': 851,
#  'update': 852,
#  'upgrade': 853,
#  'usability': 854,
#  'use': 855,
#  'user': 856,
#  'users': 857,
#  'usually': 858,
#  'vacation': 859,
#  'vehicle': 860,
#  'verizon': 861,
#  'via': 862,
#  'video': 863,
#  'videos': 864,
#  'voice': 865,
#  'wait': 866,
#  'want': 867,
#  'wash': 868,
#  'water': 869,
#  'way': 870,
#  'weather': 871,
#  'web': 872,
#  'week': 873,
#  'weeks': 874,
#  'weird': 875,
#  'well': 876,
#  'whatever': 877,
#  'whisles': 878,
#  'wi': 879,
#  'wifi': 880,
#  'wind': 881,
#  'window': 882,
#  'windows': 883,
#  'windshield': 884,
#  'wish': 885,
#  'within': 886,
#  'without': 887,
#  'withy': 888,
#  'wo': 889,
#  'wonder': 890,
#  'work': 891,
#  'world': 892,
#  'worry': 893,
#  'would': 894,
#  'write': 895,
#  'yeah': 896,
#  'year': 897,
#  'years': 898,
#  'yes': 899,
#  'yet': 900,
#  'youtube': 901}

# %% [markdown]
# ### T3

# %% [markdown]
# **What TF-IDF means:**
#
# As we learned in class, TF-IDF is short for Term Frequency - Inverse Document Frequency.  The main concept behind TF-IDF is that within a specific document, the more frequently that a word occurs then the more relevant that term is to that document (that's the Term Frequency part of TF-IDF).  However, if that same term occurs across multiple different documents then it may be less relevant overall and could simply be a commonly-occuring word (that's the Inverse Document Frequency part of TF-IDF).
#
# TF-IDF for data mining involves applying scoring to terms to weight them higher or lower in relevancy when observed within a document and also applying scoring to those terms as observed throughout multiple different documents.  Your ultimate goal with TF-IDF is to find relevant (high-scoring) words that will do a good job of summarizing an individual document.

# %% [markdown]
# ### T4

# %%
# Build a topic model using Latent Dirichlet Allocation (LDA)
# Set # of topics to 3

# Convert the vectorized data to a gensim corpus object
corpus_vect1 = gensim.matutils.Sparse2Corpus(corpus_vect, documents_columns=False)
id2word = dict((v,k) for k,v in vectorizer.vocabulary_.items())
#print(id2word)

# Build the lda model
lda1 = LdaModel(corpus_vect1, 
                num_topics=3,
                id2word=id2word, 
                passes=10)

# Print the topics
pprint(lda1.print_topics())
# Out:
# [(0,
#   '0.010*"phone" + 0.009*"well" + 0.009*"new" + 0.008*"price" + 0.008*"google" '
#   '+ 0.008*"unit" + 0.007*"cameras" + 0.007*"use" + 0.007*"say" + '
#   '0.007*"best"'),
#  (1,
#   '0.013*"camera" + 0.013*"iphone" + 0.010*"big" + 0.009*"buy" + 0.009*"take" '
#   '+ 0.008*"picture" + 0.008*"like" + 0.008*"great" + 0.007*"get" + '
#   '0.007*"really"'),
#  (2,
#   '0.014*"use" + 0.013*"camera" + 0.013*"get" + 0.011*"great" + 0.010*"phone" '
#   '+ 0.009*"would" + 0.009*"iphone" + 0.009*"one" + 0.008*"traffic" + '
#   '0.008*"easy"')]

# %%
# use the lda model to transform documents
lda_docs1 = lda1[corpus_vect1]
lda_docs1 = gensim.matutils.corpus2csc(lda_docs1)
lda_docs1 = lda_docs1.T.toarray()
#for row in lda_docs1:
#    print(row)

# extract the scores and round them to 3 decimal places
scores1 = np.round([[doc for doc in row] for row in lda_docs1], 3)
#print(scores1)

# %%
# convert the documents scores into a data frame
df_lda1 = pd.DataFrame(scores1, columns=["topic 1", "topic 2", "topic 3"])
#df_lda1

# %% [markdown]
# ### T5

# %%
# Build a topic model using Latent Dirichlet Allocation (LDA) 
# Set # of topics to 4
# Build a topic model using Latent Dirichlet Allocation (LDA)

# Convert the vectorized data to a gensim corpus object
corpus_vect2 = gensim.matutils.Sparse2Corpus(corpus_vect, documents_columns=False)
id2word = dict((v,k) for k,v in vectorizer.vocabulary_.items())
#print(id2word)

# Build the lda model
lda2 = LdaModel(corpus_vect2,
                num_topics=4,
                id2word=id2word, 
                passes=10)

# Print the topics
pprint(lda2.print_topics())
# Out:
# [(0,
#   '0.016*"iphone" + 0.014*"phone" + 0.010*"get" + 0.010*"one" + 0.010*"know" + '
#   '0.009*"great" + 0.009*"camera" + 0.008*"far" + 0.008*"keep" + '
#   '0.008*"garmin"'),
#  (1,
#   '0.021*"use" + 0.012*"picture" + 0.011*"take" + 0.010*"easy" + 0.010*"best" '
#   '+ 0.009*"iphone" + 0.009*"price" + 0.008*"camera" + 0.008*"like" + '
#   '0.008*"never"'),
#  (2,
#   '0.012*"get" + 0.012*"phone" + 0.012*"would" + 0.009*"love" + 0.008*"multi" '
#   '+ 0.008*"well" + 0.008*"look" + 0.008*"go" + 0.007*"recommend" + '
#   '0.007*"make"'),
#  (3,
#   '0.018*"camera" + 0.011*"need" + 0.011*"happy" + 0.011*"battery" + '
#   '0.010*"life" + 0.010*"great" + 0.010*"like" + 0.009*"buy" + 0.009*"traffic" '
#   '+ 0.009*"canon"')]

# %%
# use the lda model to transform documents
lda_docs2 = lda2[corpus_vect2]
lda_docs2 = gensim.matutils.corpus2csc(lda_docs2)
lda_docs2 = lda_docs2.T.toarray()
#for row in lda_docs2:
#    print(row)

# extract the scores and round them to 3 decimal places
scores2 = np.round([[doc for doc in row] for row in lda_docs2], 3)
#print(scores2)

# %%
# convert the documents scores into a data frame
df_lda2 = pd.DataFrame(scores2, columns=["topic 1", "topic 2", "topic 3", "topic 4"])
#df_lda2

# %% [markdown]
# ### T6

# %%
# Build a topic model using Latent Dirichlet Allocation (LDA)
# Set # of topics to 5

# Convert the vectorized data to a gensim corpus object
corpus_vect3 = gensim.matutils.Sparse2Corpus(corpus_vect, documents_columns=False)
id2word = dict((v,k) for k,v in vectorizer.vocabulary_.items())
#print(id2word)

# Build the lda model
lda3 = LdaModel(corpus_vect3,
                num_topics=5,
                id2word=id2word, 
                passes=10)

# Print the topics
pprint(lda3.print_topics())
# Out:
# [(0,
#   '0.017*"take" + 0.014*"picture" + 0.013*"best" + 0.012*"camera" + '
#   '0.012*"great" + 0.011*"like" + 0.011*"review" + 0.010*"buy" + 0.009*"far" + '
#   '0.009*"battery"'),
#  (1,
#   '0.015*"easy" + 0.012*"use" + 0.010*"traffic" + 0.010*"iphone" + '
#   '0.010*"phone" + 0.009*"price" + 0.009*"one" + 0.009*"poi" + 0.009*"love" + '
#   '0.009*"camera"'),
#  (2,
#   '0.011*"garmin" + 0.009*"like" + 0.009*"also" + 0.009*"signal" + '
#   '0.009*"highway" + 0.008*"camera" + 0.008*"use" + 0.008*"bluetooth" + '
#   '0.008*"thing" + 0.007*"little"'),
#  (3,
#   '0.013*"use" + 0.013*"phone" + 0.011*"unit" + 0.010*"say" + 0.010*"nikon" + '
#   '0.009*"camera" + 0.009*"recommend" + 0.008*"one" + 0.008*"better" + '
#   '0.008*"quality"'),
#  (4,
#   '0.019*"iphone" + 0.018*"get" + 0.014*"much" + 0.013*"phone" + 0.012*"would" '
#   '+ 0.010*"buy" + 0.010*"love" + 0.010*"shoot" + 0.009*"great" + '
#   '0.009*"point"')]

# %%
# use the lda model to transform documents
lda_docs3 = lda3[corpus_vect3]
lda_docs3 = gensim.matutils.corpus2csc(lda_docs3)
lda_docs3 = lda_docs3.T.toarray()
#for row in lda_docs3:
#    print(row)

# extract the scores and round them to 3 decimal places
scores3 = np.round([[doc for doc in row] for row in lda_docs3], 3)
#print(scores3)

# %%
# convert the documents scores into a data frame
df_lda3 = pd.DataFrame(scores3, columns=["topic 1", "topic 2", "topic 3", "topic 4", "topic5"])
#df_lda3

# %% [markdown]
# ### T7

# %% [markdown]
# Q: Among T4, T5, T6 results, which number of topics (among 3,4,5) gives you the best topic modeling results?
#
# A: The results of T4 (3 topics) seems to give the most coherent collections of words for each topic.
#
# The results of having 5 topics gives several groups of words that don't give a strong understanding of what the topic actually is about, for example this group of words:
#
#  (2,
#   '0.011*"use" + 0.011*"get" + 0.011*"great" + 0.010*"take" + 0.010*"go" + '
#   '0.010*"much" + 0.010*"like" + 0.009*"sometimes" + 0.008*"battery" + '
#   '0.008*"image"'),
#
# Having only 4 topics is a bit more coherent than 5, but still produces this word grouping that is difficult to generalize into a topic:
#
#  (3,
#   '0.013*"phone" + 0.013*"one" + 0.012*"need" + 0.011*"use" + 0.011*"iphone" + '
#   '0.010*"battery" + 0.010*"apps" + 0.009*"make" + 0.009*"multi" + '
#   '0.009*"take"')]
#
# Ultimately, I think a setting of 3 topics is the best fit as it gives the most coherent word groupings as compared to the other two alternatives.

# %% [markdown]
# ### T8

# %%
# Re-run the TF-IDF vectorizer, set norm to be “l1” for the vectorizer
# Set num_topics to be the optimal number of topics you found in T7 and re-run LDA
vectorizer_l1 = TfidfVectorizer(tokenizer=LemmaTokenizer(),
                                norm="l1",
                                stop_words=stopwords,
                                max_df=0.9, # remove frequent words (> 90%)
                                min_df=1) # remove unique words

corpus_vect_l1 = vectorizer_l1.fit_transform(docs1)
#print(corpus_vect_l1) # sparse matrix

# %%
# Build a topic model using Latent Dirichlet Allocation (LDA)
# Set # of topics to 3

# Convert the vectorized data to a gensim corpus object
corpus_vect_l1 = gensim.matutils.Sparse2Corpus(corpus_vect, documents_columns=False)
id2word = dict((v,k) for k,v in vectorizer_l1.vocabulary_.items())
#print(id2word)

# Build the lda model
lda_l1 = LdaModel(corpus_vect_l1,
                  num_topics=3,
                  id2word=id2word,
                  passes=10)

# Print the topics
pprint(lda_l1.print_topics())
# Out:
# [(0,
#   '0.013*"camera" + 0.013*"phone" + 0.012*"one" + 0.011*"think" + 0.010*"buy" '
#   '+ 0.009*"like" + 0.008*"get" + 0.008*"go" + 0.008*"happy" + 0.007*"shoot"'),
#  (1,
#   '0.012*"great" + 0.012*"camera" + 0.010*"iphone" + 0.010*"well" + '
#   '0.009*"unit" + 0.009*"also" + 0.009*"price" + 0.008*"use" + 0.007*"phone" + '
#   '0.007*"traffic"'),
#  (2,
#   '0.013*"iphone" + 0.012*"picture" + 0.012*"get" + 0.011*"use" + 0.010*"take" '
#   '+ 0.009*"good" + 0.008*"screen" + 0.008*"phone" + 0.008*"easy" + '
#   '0.008*"rout"')]

# %%
# use the lda model to transform documents
lda_docs_l1 = lda_l1[corpus_vect_l1]
lda_docs_l1 = gensim.matutils.corpus2csc(lda_docs_l1)
lda_docs_l1 = lda_docs_l1.T.toarray()
#for row in lda_docs_l1:
#    print(row)

# extract the scores and round them to 3 decimal places
scores_l1 = np.round([[doc for doc in row] for row in lda_docs_l1], 3)
#print(scores_l1)

# %%
# convert the documents scores into a data frame
df_lda_l1 = pd.DataFrame(scores_l1, columns=["topic 1", "topic 2", "topic 3"])
#df_lda_l1

# %% [markdown]
# ### T9

# %%
# Re-run the TF-IDF vectorizer, set norm to be “l2” for the vectorizer
# Set num_topics to be the optimal number of topics you found in T7 and re-run LDA
vectorizer_l2 = TfidfVectorizer(tokenizer=LemmaTokenizer(),
                                norm="l2",
                                stop_words=stopwords,
                                max_df=0.9, # remove frequent words (> 90%)
                                min_df=1) # remove unique words

corpus_vect_l2 = vectorizer_l2.fit_transform(docs1)
#print(corpus_vect_l2) # sparse matrix

# %%
# Build a topic model using Latent Dirichlet Allocation (LDA)
# Set # of topics to 3

# Convert the vectorized data to a gensim corpus object
corpus_vect_l2 = gensim.matutils.Sparse2Corpus(corpus_vect, documents_columns=False)
id2word = dict((v,k) for k,v in vectorizer_l2.vocabulary_.items())
#print(id2word)

# Build the lda model
lda_l2 = LdaModel(corpus_vect_l2,
                  num_topics=3,
                  id2word=id2word,
                  passes=10)

# Print the topics
pprint(lda_l2.print_topics())
# Out:
# [(0,
#   '0.020*"iphone" + 0.015*"get" + 0.012*"phone" + 0.012*"one" + 0.011*"use" + '
#   '0.008*"love" + 0.008*"would" + 0.008*"well" + 0.008*"go" + 0.008*"like"'),
#  (1,
#   '0.016*"great" + 0.012*"camera" + 0.010*"use" + 0.010*"take" + '
#   '0.009*"picture" + 0.008*"phone" + 0.008*"easy" + 0.008*"best" + '
#   '0.008*"traffic" + 0.008*"anyone"'),
#  (2,
#   '0.014*"camera" + 0.010*"price" + 0.009*"screen" + 0.009*"like" + '
#   '0.008*"battery" + 0.007*"picture" + 0.007*"cameras" + 0.007*"video" + '
#   '0.007*"shoot" + 0.007*"also"')]

# %%
# use the lda model to transform documents
lda_docs_l2 = lda_l2[corpus_vect_l2]
lda_docs_l2 = gensim.matutils.corpus2csc(lda_docs_l2)
lda_docs_l2 = lda_docs_l2.T.toarray()
#for row in lda_docs_l2:
#    print(row)

# extract the scores and round them to 3 decimal places
scores_l2 = np.round([[doc for doc in row] for row in lda_docs_l2], 3)
#print(scores_l2)

# %%
# convert the documents scores into a data frame
df_lda_l2 = pd.DataFrame(scores_l2, columns=["topic 1", "topic 2", "topic 3"])
#df_lda_l2

# %% [markdown]
# ### T10

# %% [markdown]
# ***Q:*** Compare the topics you obtained with norm set to be 1) None, 2) “l1” or 3) “l2” (num_topics is always the optimal number of topics you identified in T7). Please tell me which norm gives you the best topics, and why.
#
# ***A:*** The norm set to "None" seems to give me the best topics, alongside the optimal number of topics that I chose in T7 (3 topics).  Of the 3 norm options, the "None" norm results seem to have the best distinction of topics.
#
# For the "None" results, the first topic has nouns such as "camera" and "picture".  The second topic has nouns such as "price" and "screen".  The third sopic contains nouns such as "unit" and "traffic".  These all seem to be distinct from one another and could each be attributable back to a discrete topic
#
# The "l1" norm results has nouns such as "camera" that appear in more than one topic.  The "l2" norm results are short on nouns, and contain lots of adjectives or adverbs, and are tough to make a distinction on what the topic may be about.
#
# Ultimately, because of the better clarity and distinction, I think the results from the "None" group are the best and make the most sense.

# %% [markdown]
# ### T11

# %%
# Write code to show the topic/document table of LDA with the best number of topics 
# using the vectorized dataset obtained with the best norm

# convert the documents scores into a data frame
df_lda1 = pd.DataFrame(scores1, columns=["topic 1", "topic 2", "topic 3"])
df_lda1
# Out:
#      topic 1  topic 2  topic 3
# 0      0.981    0.010    0.000
# 1      0.967    0.017    0.017
# 2      0.993    0.000    0.000
# 3      0.000    0.989    0.000
# 4      0.000    0.011    0.980
# 5      0.000    0.000    0.984
# 6      0.028    0.939    0.032
# 7      0.990    0.000    0.000
# 8      0.000    0.000    0.991
# 9      0.000    0.982    0.000
# 10     0.000    0.983    0.000
# 11     0.011    0.978    0.011
# 12     0.000    0.183    0.812
# 13     0.152    0.498    0.350
# 14     0.014    0.015    0.971
# 15     0.018    0.019    0.963
# 16     0.011    0.012    0.977
# 17     0.036    0.040    0.925
# 18     0.017    0.018    0.965
# 19     0.000    0.994    0.000
# 20     0.928    0.036    0.037
# 21     0.956    0.022    0.021
# 22     0.927    0.037    0.036
# 23     0.019    0.019    0.962
# 24     0.000    0.000    0.997
# 25     0.014    0.013    0.973
# 26     0.011    0.284    0.705
# 27     0.015    0.609    0.376
# 28     0.974    0.014    0.013
# 29     0.017    0.966    0.017
# ..       ...      ...      ...
# 205    0.000    0.000    0.983
# 206    0.000    0.000    0.996
# 207    0.011    0.979    0.010
# 208    0.022    0.021    0.957
# 209    0.014    0.972    0.015
# 210    0.000    0.988    0.000
# 211    0.943    0.029    0.028
# 212    0.000    0.000    0.985
# 213    0.982    0.000    0.000
# 214    0.000    0.981    0.000
# 215    0.988    0.000    0.000
# 216    0.000    0.000    0.984
# 217    0.950    0.024    0.026
# 218    0.000    0.000    0.994
# 219    0.980    0.011    0.000
# 220    0.000    0.995    0.000
# 221    0.987    0.000    0.000
# 222    0.000    0.000    0.987
# 223    0.040    0.043    0.917
# 224    0.982    0.000    0.000
# 225    0.988    0.000    0.000
# 226    0.000    0.000    0.992
# 227    0.415    0.575    0.010
# 228    0.000    0.989    0.000
# 229    0.018    0.019    0.963
# 230    0.000    0.979    0.011
# 231    0.000    0.000    0.986
# 232    0.901    0.049    0.049
# 233    0.000    0.986    0.000
#  [ 1.8280e+00  2.5000e-01 -1.7000e-02]
#  [ 2.0000e-01  1.9000e-02 -7.3000e-02]
#  [ 2.5350e+00 -1.1480e+00  6.7100e-01]
#  [ 2.9100e-01 -4.6000e-02  1.2600e-01]
#  [ 1.6370e+00  6.3000e-02  1.1100e-01]
#  [ 2.4560e+00 -1.0830e+00 -1.9600e-01]
#  [ 1.1810e+00 -9.5000e-02  2.9600e-01]
#  [ 2.6000e-01 -1.3500e-01  5.0000e-03]
#  [ 4.4370e+00  6.3100e-01 -9.4700e-01]
#  [ 2.5240e+00  7.4200e-01 -1.4600e-01]
#  [ 5.9530e+00 -1.3260e+00 -8.1800e-01]
#  [ 8.0100e-01 -7.3300e-01 -8.3000e-02]
#  [ 2.5670e+00 -1.5580e+00 -1.4260e+00]
#  [ 9.3500e-01 -9.1000e-02 -2.5200e-01]
#  [ 1.7520e+00  3.5800e-01  8.1000e-02]
#  [ 1.3040e+00 -7.7900e-01 -2.7700e-01]
#  [ 5.4070e+00 -4.4160e+00  2.8400e-01]
#  [ 4.2740e+00  1.2260e+00 -8.1300e-01]
#  [ 1.0720e+00 -1.2180e+00  1.1100e-01]
#  [ 1.1340e+00  8.3500e-01  6.6000e-02]
#  [ 7.4100e-01 -5.0500e-01  6.8000e-02]
#  [ 3.7220e+00 -3.2250e+00 -2.1600e-01]
#  [-0.0000e+00 -0.0000e+00  0.0000e+00]
#  [ 3.9140e+00  6.5500e-01 -8.3500e-01]
#  [ 2.1500e-01 -1.1500e-01  6.6000e-02]]
# [41.00733316 35.58807373 33.64310536]

# %%
df_comp = pd.DataFrame(tsvd.components_, columns=vectorizer.get_feature_names())
df_comp = df_comp.apply(lambda x: np.round(x,3))
print(df_comp)
# Out:
#    1000fd   16gb  265wt    2nd    30k   32mb     3g    3gs     4g   765t  ...  \
# 0   0.003  0.003  0.003  0.045  0.003  0.005  0.020  0.003  0.025  0.007  ...
# 1  -0.000 -0.005 -0.001 -0.053 -0.004  0.003 -0.023 -0.005 -0.016  0.002  ...
# 2  -0.000  0.000 -0.001 -0.045 -0.001 -0.001  0.162  0.000 -0.002  0.004  ...
#
#    world  worry  would  write   yeah   year  years    yes    yet  youtube
# 0  0.040  0.004  0.140    0.0  0.009  0.028  0.053  0.028  0.021    0.009
# 1 -0.053 -0.000 -0.170    0.0 -0.010 -0.029 -0.017 -0.036 -0.007   -0.003
# 2  0.002  0.002 -0.036    0.0 -0.006  0.002 -0.013 -0.007  0.014    0.011
#
# [3 rows x 902 columns]

# %%
# using the LsiModel class in gensim
lsi = LsiModel(corpus=corpus_vect1, 
               id2word=id2word, 
               num_topics=3)

# %%
# Print a list of topics
pprint(lsi.print_topics())
# Out:
# [(0,
#   '0.255*"like" + 0.196*"camera" + 0.184*"screen" + 0.180*"picture" + '
#   '0.157*"way" + 0.154*"use" + 0.146*"get" + 0.143*"take" + 0.141*"would" + '
#   '0.138*"quality"'),
#  (1,
#   '-0.205*"screen" + -0.200*"picture" + 0.190*"way" + 0.170*"would" + '
#   '0.164*"phone" + 0.154*"highway" + -0.122*"note" + -0.121*"file" + '
#   '-0.121*"garage" + -0.121*"dead"'),
#  (2,
#   '0.312*"signal" + 0.163*"3g" + 0.160*"customizable" + 0.160*"wi" + '
#   '0.160*"theme" + 0.160*"generally" + 0.160*"autolock" + 0.160*"settings" + '
#   '0.160*"ssh" + 0.160*"strong"')]

# %%
# use the lsi model to transform documents
lsi_docs = lsi[corpus_vect1]
lsi_docs = gensim.matutils.corpus2csc(lsi_docs)
lsi_docs = lsi_docs.T.toarray()
#for row in lsi_docs:
#    print(row)

# extract the scores and round them to 3 decimal places
scores_lsi = np.round([[doc for doc in row] for row in lsi_docs], 3)
#print(scores_lsi)

# %%
# Print scores
# convert the documents scores into a data frame
df_lsi = pd.DataFrame(scores_lsi, columns=["topic 1", "topic 2", "topic 3"])
df_lsi
# Out:
#      topic 1  topic 2  topic 3
# 0      1.147    1.268   -0.023
# 1      0.149    0.018   -0.011
# 2      3.211    2.635   -0.363
# 3      1.682    1.533    0.921
# 4      1.000    0.638   -0.375
# 5      0.937    0.471   -0.035
# 6      0.996   -0.318    0.030
# 7      3.924    2.678   -0.808
# 8      3.577    1.878    0.046
# 9      1.893    1.313   -0.283
# 10     1.326    0.140   -0.078
# 11     0.474    0.036   -0.111
# 12     3.435    2.708    0.318
# 13     3.526   -0.359   -0.502
# 14     0.021   -0.006    0.002
# 15     0.652    0.633    0.029
# 16     0.614    0.087   -0.076
# 17     1.000    0.839    0.057
# 18     1.650   -0.551   -0.103
# 19     5.436    6.670   -0.793
# 20     0.193    0.082   -0.023
# 21     0.270    0.053   -0.019
# 22     0.905    0.251   -0.280
# 23     0.049   -0.001    0.026
# 24    18.964  -26.543    2.138
# 25     1.342    1.532   -0.315
# 26     0.691    0.721   -0.174
# 27     0.883    0.207   -0.012
# 28     2.049   -0.258    0.367
# 29     2.172   -1.038   -0.248
# ..       ...      ...      ...
# 205    1.401    1.116    0.202
# 206    4.773    4.832   31.460
# 207    0.269    0.176    0.108
# 208    1.470    0.953   -0.271
# 209    0.556    0.476   -0.006
# 210    1.827   -0.263   -0.167
# 211    0.200   -0.024   -0.073
# 212    2.532    1.192    0.575
# 213    0.289    0.038    0.106
# 214    1.632   -0.003    0.149
# 215    2.445    1.126   -0.232
# 216    1.176    0.189    0.200
# 217    0.261    0.140    0.023
# 218    4.488   -0.837   -0.306
# 219    2.525   -0.711   -0.159
# 220    5.953    1.382   -1.077
# 221    0.820    0.697    0.015
# 222    2.566    1.533   -1.336
# 223    0.933    0.092   -0.233
# 224    1.754   -0.360    0.040
# 225    1.306    0.761   -0.279
# 226    5.381    4.483    0.221
# 227    4.269   -1.243   -0.917
# 228    1.062    1.252    0.023
# 229    1.132   -0.841   -0.054
# 230    0.739    0.525    0.067
# 231    3.712    3.255   -0.293
# 232   -0.000    0.000    0.000
# 233    3.913   -0.587   -0.738
# 234    0.214    0.111    0.018
#
# [235 rows x 3 columns]
